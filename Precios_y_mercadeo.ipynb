# %% [markdown]
# # Clase de clasificación de riesgo
#
# A partir del conocimiento del tipo de riesgo que tiene un cliente podemos determinar un precio a ese riesgo mediante polizas o seguros.

# %%
import numpy as np # Esto importa el paquete
import matplotlib.pyplot as plt

# Definir el rango de x
x = np.linspace(1, 50, 1000)

# Funciones
def funcion_amante(x):
    return np.exp(x)

def funcion_averso(x):
    return np.sqrt(x)

def funcion_neutral(x):
    return 0.5 * x + 1

def funcion_logaritmica(x):
    return np.log(x)

# Crear la figura y los subplots
fig, axs = plt.subplots(1, 4, figsize=(15, 5))

# Gráfico 1: Función Amante
axs[0].plot(x, funcion_amante(x), label="Amante")
axs[0].set_title("Función Amante al riesgo")
axs[0].legend()

# Gráfico 2: Función Averso
axs[1].plot(x, funcion_averso(x), label="Averso")
axs[1].set_title("Función Averso al riesgo")
axs[1].legend()

# Gráfico 3: Función Neutral
axs[2].plot(x, funcion_neutral(x), label="Neutral al Riesgo")
axs[2].set_title("Función Neutral al Riesgo")
axs[2].legend()

# Gráfico 4: Función Logaritmica
axs[3].plot(x, funcion_logaritmica(x), label="Con logaritmo Riesgo")
axs[3].set_title("Función logaritmo")
axs[3].legend()


# Ajustar el espaciado entre subplots
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %%
# Datos de las tres loterías
loteria1 = [(100000, 0.5), (-50000, 0.5)]
loteria2 = [(200000, 0.5), (-100000, 0.5)]
loteria3 = [(20000000, 0.5), (-10000000, 0.5)]

# Función para calcular el valor esperado
def cal_valor_esperado(loteria):
    valor_esperado = 0
    for resultado, probabilidad in loteria:
        valor_esperado += resultado * probabilidad
    return valor_esperado

# Calcular valor esperado para cada lotería
valor_esperado1 = cal_valor_esperado(loteria1)
valor_esperado2 = cal_valor_esperado(loteria2)
valor_esperado3 = cal_valor_esperado(loteria3)

# Imprimir los resultados
print("Valor Esperado Lotería 1:", valor_esperado1)
print("Valor Esperado Lotería 2:", valor_esperado2)
print("Valor Esperado Lotería 3:", valor_esperado3)

# Encontrar la lotería con el valor esperado más alto
loterias = {valor_esperado1: "Lotería 1", valor_esperado2: "Lotería 2", valor_esperado3: "Lotería 3"}
mejor_loteria = loterias[max(valor_esperado1, valor_esperado2, valor_esperado3)]

print("La mejor lotería es:", mejor_loteria)
# Out:
# Valor Esperado Lotería 1: 25000.0
# Valor Esperado Lotería 2: 50000.0
# Valor Esperado Lotería 3: 5000000.0
# La mejor lotería es: Lotería 3

# %%
# Datos de las tres loterías de Mateo
loteria1 = [(10100000, 0.5), (9950000, 0.5)]
loteria2 = [(10200000, 0.5), (9900000, 0.5)]
loteria3 = [(30000000, 0.5), (0, 0.5)]

# Función para calcular la utilidad esperada
def cal_utilidad_esperada(loteria):
    utilidad_esperada = 0
    for resultado, probabilidad in loteria:
        utilidad_esperada += (resultado)**0.5 * probabilidad
    return utilidad_esperada

# Calcular utilidad esperada para cada lotería
utilidad_esperada1 = cal_utilidad_esperada(loteria1)
utilidad_esperada2 = cal_utilidad_esperada(loteria2)
utilidad_esperada3 = cal_utilidad_esperada(loteria3)

# Imprimir los resultados de utilidad esperada
print("Utilidad Esperada Lotería 1:", utilidad_esperada1)
print("Utilidad Esperada Lotería 2:", utilidad_esperada2)
print("Utilidad Esperada Lotería 3:", utilidad_esperada3)

# Encontrar la lotería con la utilidad esperada más alta
utilidad_loterias = {utilidad_esperada1: "Lotería 1", utilidad_esperada2: "Lotería 2", utilidad_esperada3: "Lotería 3"}
Mejor_loteria = utilidad_loterias[max(utilidad_esperada1, utilidad_esperada2, utilidad_esperada3)]

print("La mejor lotería en términos de utilidad esperada es la:", Mejor_loteria)
# Out:
# Utilidad Esperada Lotería 1: 3166.205887765821
# Utilidad Esperada Lotería 2: 3170.0852145223585
# Utilidad Esperada Lotería 3: 2738.6127875258308
# La mejor lotería en términos de utilidad esperada es la: Lotería 2

# %%
import numpy as np

# Datos de las tres loterías de Mateo
loteria1 = [(810000, 0.1), (360000, 0.5), (110000, 0.4)]
loteria2 = [(250000, 1)] # Modificar
loteria3 = [(450000, 0.3), (170000, 0.7)]

# Función para calcular la utilidad esperada
def cal_utilidad_esperada(loteria):
    utilidad_esperada = 0
    for resultado, probabilidad in loteria:
        utilidad_esperada += np.log(resultado) * probabilidad
    return utilidad_esperada

# Calcular utilidad esperada para cada lotería
utilidad_esperada1 = cal_utilidad_esperada(loteria1)
utilidad_esperada2 = cal_utilidad_esperada(loteria2)
utilidad_esperada3 = cal_utilidad_esperada(loteria3)

# Imprimir los resultados de utilidad esperada
print("Utilidad Esperada Lotería 1:", utilidad_esperada1)
print("Utilidad Esperada Lotería 2:", utilidad_esperada2)
print("Utilidad Esperada Lotería 3:", utilidad_esperada3)

# Encontrar la lotería con la utilidad esperada más alta
utilidad_loterias = {utilidad_esperada1: "Lotería 1", utilidad_esperada2: "Lotería 2", utilidad_esperada3: "Lotería 3"}
Mejor_loteria = utilidad_loterias[max(utilidad_esperada1, utilidad_esperada2, utilidad_esperada3)]

print("La mejor lotería en términos de utilidad esperada es la:", Mejor_loteria)
# Out:
# Utilidad Esperada Lotería 1: 12.40070286579083
# Utilidad Esperada Lotería 2: 12.429216196844383
# Utilidad Esperada Lotería 3: 12.335588459746628
# La mejor lotería en términos de utilidad esperada es la: Lotería 2

# %% [markdown]
# Vamos a la parte de precios. Para esto, debemos tener presente que un individuo siempre se va a asegurar siempre y cuando se considere **averso** al riesgo.

# %%
# Datos de las tres loterías
loteria1 = [(810000, 0.1), (360000, 0.5), (110000, 0.4)]
loteria2 = [(250000, 1)] # Modificar
loteria3 = [(450000, 0.3), (170000, 0.7)]

# Función de utilidad
def funcion_utilidad(x):
    return np.log(x)

# Función para calcular el valor esperado
def cal_valor_esperado(loteria):
    valor_esperado = 0
    for resultado, probabilidad in loteria:
        valor_esperado += resultado * probabilidad
    return valor_esperado

# Calcular valor esperado para cada lotería
valor_esperado1 = cal_valor_esperado(loteria1)
valor_esperado2 = cal_valor_esperado(loteria2)
valor_esperado3 = cal_valor_esperado(loteria3)

# Función para calcular la utilidad esperada
def cal_utilidad_esperada(loteria):
    utilidad_esperada = 0
    for resultado, probabilidad in loteria:
        utilidad_esperada += np.log(resultado) * probabilidad
    return utilidad_esperada

# Calcular utilidad esperada para cada lotería
utilidad_esperada1 = cal_utilidad_esperada(loteria1)
utilidad_esperada2 = cal_utilidad_esperada(loteria2)
utilidad_esperada3 = cal_utilidad_esperada(loteria3)

# Función de utilidad
def funcion_utilidad(x):
    return np.exp(x) # al ser logaritmo se aplica el exponencial (e)

# Calcular equivalente de certeza como la utilidad de un monto seguro equivalente
equivalente_certeza1 = funcion_utilidad(utilidad_esperada1)
equivalente_certeza2 = funcion_utilidad(utilidad_esperada1)
equivalente_certeza3 = funcion_utilidad(utilidad_esperada1)

# Calcular la prima de riesgo como la diferencia entre el valor esperado y el equivalente de certeza
Prima_riesgo1 = valor_esperado1 - equivalente_certeza1
Prima_riesgo2 = valor_esperado2 - equivalente_certeza2
Prima_riesgo3 = valor_esperado3 - equivalente_certeza3

# Imprimir los resultados de la prima de riesgo
print("Prima de Riesgo Lotería 1:", Prima_riesgo1)
print("Prima de Riesgo Lotería 2:", Prima_riesgo2)
print("Prima de Riesgo Lotería 3:", Prima_riesgo3)
# Out:
# Prima de Riesgo Lotería 1: 62027.66556225851
# Prima de Riesgo Lotería 2: 7027.665562258509
# Prima de Riesgo Lotería 3: 11027.66556225851

# %% [markdown]
# Lo que indica el precio que debe pagar por cada loteria para que no le ocurra ese suceso. Para la loteria 1 esta dispuesto/a a pagar $62.028
